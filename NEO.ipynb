# %% [markdown]
# # Set Up

# %%
# !pip install sentence_transformers
# Out:
# ...
#      |████████████████████████████████| 79 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 27.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 27.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 58.4 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=e7e5ffa52ae2143f2467c66f136e1479194e4e2a7b07bdf470cde4def5e97719
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import gensim
import scipy
from scipy.spatial import distance
import pandas
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
from matplotlib import figure
import statistics as s
from matplotlib import ticker
import re
import math
import os

# %%
# need to research which model would work best
sbert_model = SentenceTransformer('nli-bert-large')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/377 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
path = os.getcwd()
print(path)
# Out:
# /content

# %%
from EP1_23_BERT_vs_Human import *

def utterances_examined(file):
    print("Filename:", file)
    os.chdir(
        "/content")
    print("Directory:", os.getcwd())
    file_contents = pandas.read_excel(file)
    speaker = file_contents['Speaker']
    line = file_contents['Turn']
    print(line[0])
    line_set = []

    for index in range(len(line)):
        line_set.append(line[index])

    # option 1 = average similarity, option 2 = BERT vs Human 
    option = 2

    if file == "Team #23 Experimenter Participant 1.xlsx" and option == 2:
      phase_by_human = file_contents['Broad Phase']
      # generate_graph_23(line_set, str(file[0:len(file) - 5]), phase_by_human)
    else:
      generate_graph(line_set, str(file[0:len(file) - 5]))

file_list = []
directory = os.path.normpath(
    "/content")
for subdir, dirs, files in os.walk(directory):
    for file in files:
        if file.endswith(".xlsx") and file.count("~$") == 0:
            file.encode("utf-8")
            file_list.append(file)

for index in range(len(file_list)):
    print(file_list[index])
    # print(str(file_list[index][0:len(file_list[index]) - 5]))
    # if file_list[index] == "Team #23 Participants Only.xlsx" or file_list[index].count("Team #12") == 1:
        #print(str(file_list[index][0:len(file_list[index]) - 5]))
    utterances_examined(file_list[index])
# Out:
# Team #3 Participants Only.xlsx
# Filename: Team #3 Participants Only.xlsx
# Directory: /content
# We are marking the EEG recording now.
# Length of line: 57
# Phases Similarity Array: [0.4173401892185211, 0.44029873609542847, 0.5729723572731018, 0.4934997856616974]
# Maximum of Phases Similarity Array: 0.5729723572731018
# Index of Maximum of Phases Similarity Array: 2
# Phase 0 words Google Docs
# Phase 0 words PDF
# Phase 0 words hear
# Phase 0 words shift key
# Phase 0 words hello
# Phase 0 words EEG
# Count 6
# Iteration + window + 1: 7
# Phases Similarity Array: [0.4337760806083679, 0.5525034070014954, 0.4790777564048767]
# Maximum of Phases Similarity Array: 0.5525034070014954
# Index of Maximum of Phases Similarity Array: 1
# Phase 0 words Google Docs
# Phase 0 words PDF
# Phase 0 words hear
# Phase 0 words shift key
# Phase 0 words hello
# Phase 0 words EEG
# Count 6
# Iteration + window + 1: 8
# ...
